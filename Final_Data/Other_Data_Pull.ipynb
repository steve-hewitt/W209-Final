# %%
import requests
import json
import pandas as pd
import altair as alt

# %% [markdown]
# # API Pull

# %%
# Import list of targeted CPI-U cateogires.
targets = pd.read_excel("Other_BLS_Data.xlsx", header=0)
targets
# Out:
#                                  Category Name      Series ID          Type  \
# 0                        Earnings - All People  LEU0252881500      Earnings
# 1                               Earnings - Men  LEU0252881800      Earnings
# 2                             Earnings - Women  LEU0252882700      Earnings
# 3                      Earnings - White People  LEU0252883600      Earnings
# 4                         Earnings - White Men  LEU0252883900      Earnings
# 5                       Earnings - White Women  LEU0252884200      Earnings
# 6                      Earnings - Black People  LEU0252884500      Earnings
# 7                         Earnings - Black Men  LEU0252884800      Earnings
# 8                       Earnings - Black Women  LEU0252885100      Earnings
# 9                      Earnings - Asian People  LEU0254468400      Earnings
# 10                        Earnings - Asian Men  LEU0254468500      Earnings
# 11                      Earnings - Asian Women  LEU0254468600      Earnings
# 12                  Earnings - Hispanic People  LEU0252885400      Earnings
# 13                     Earnings - Hispanic Men  LEU0252885700      Earnings
# 14                   Earnings - Hispanic Women  LEU0252886000      Earnings
# 15           Earnings - High School Unfinished  LEU0252916700      Earnings
# 16             Earnings - High School Finished  LEU0252917300      Earnings
# 17                     Earnings - Some College  LEU0254929400      Earnings
# 18                Earnings - Bachelor's Degree  LEU0252919100      Earnings
# 19                  Earnings - Advanced Degree  LEU0252919700      Earnings
# 20              Unemployment Rate - All People    LNS14000000  Unemployment
# 21                     Unemployment Rate - Men    LNS14000001  Unemployment
# 22                   Unemployment Rate - Women    LNS14000002  Unemployment
# 23            Unemployment Rate - White People    LNS14000003  Unemployment
# 24            Unemployment Rate - Black People    LNS14000006  Unemployment
# 25            Unemployment Rate - Asian People    LNS14032183  Unemployment
# 26         Unemployment Rate - Hispanic People    LNS14000009  Unemployment
# 27  Unemployment Rate - High School Unfinished    LNS14027659  Unemployment
# 28    Unemployment Rate - High School Finished    LNS14027660  Unemployment
# 29            Unemployment Rate - Some College    LNS14027689  Unemployment
# 30   Unemployment Rate - Bachelor's and Higher    LNS14027662  Unemployment
#
#              Bucket
# 0               Top
# 1            Gender
# 2            Gender
# 3              Race
# 4   Race and Gender
# 5   Race and Gender
# 6              Race
# 7   Race and Gender
# 8   Race and Gender
# 9              Race
# 10  Race and Gender
# 11  Race and Gender
# 12             Race
# 13  Race and Gender
# 14  Race and Gender
# 15        Education
# 16        Education
# 17        Education
# 18        Education
# 19        Education
# 20              Top
# 21           Gender
# 22           Gender
# 23             Race
# 24             Race
# 25             Race
# 26             Race
# 27        Education
# 28        Education
# 29        Education
# 30        Education

# %%
def API_call(series_ids, start_year, end_year):
    '''
    Calls the BLS API to return data. Returns a DataFrame with the combined results.
    '''
    
    ### MAKE SURE TO SET YOUR API KEY BELOW.
    api_key = 'XXXXX'
    
    # Build message to send to API.
    headers = {'Content-type': 'application/json'}
    data = json.dumps({"seriesid": series_ids,"startyear":start_year, "endyear":end_year, "registrationkey":api_key})
    p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)

    # Parse results.
    j = json.loads(p.text)
    dfs = []
    for x in range(0,len(j["Results"]['series'])):
        t_df = pd.DataFrame(j["Results"]['series'][x]['data'])
        t_df['series'] = j["Results"]['series'][x]['seriesID']
        dfs.append(t_df)
    df = pd.concat(dfs)
    
    return df

# %%
# Split query inputs into chunks that fit in the API limit.
year_ranges = [(x,x+19) for x in range(1970,2021,20)]
series_ids = list(targets['Series ID'])
series_id_groups = [series_ids[0:50]]

# Send API requests and combine into a single DataFrame
df = pd.concat([API_call(series_id_groups[y], year_ranges[x][0], year_ranges[x][1]) for x in range(0,3) for y in range(0,1)])

# %%
# Merge other data into results from API pull.
series_names = targets.set_index('Series ID').to_dict()['Category Name']
df['Category'] = df['series'].map(series_names)
types = targets.set_index('Series ID').to_dict()['Type']
df['Type'] = df['series'].map(types)
buckets = targets.set_index('Series ID').to_dict()['Bucket']
df['Bucket'] = df['series'].map(buckets)

# Convert quarter names to months.
df['period'].replace(to_replace = ['Q01', 'Q02', 'Q03', 'Q04'], value = ['M01', 'M04', 'M07', 'M10'], inplace = True)

# Convert month and year to a datetime column.
df['date'] = pd.to_datetime(df.year.astype(str) + '/' + df.period.str[1:] + '/01')

# %%
# Make sure values are stored as numbers and not as strings.
df.value = df.value.astype(float)
df.year = df.year.astype(int)

# Save DataFrame as pickle.
df.to_pickle("other_data_final.pkl")

# Load DataFrame from pickle.
#df = pd.read_pickle("data.pkl")

# Check to see that format looks correct.
df
# Out:
#      year period   periodName  value footnotes         series latest  \
# 0    1989    M10  4th Quarter  408.0      [{}]  LEU0252881500    NaN
# 1    1989    M07  3rd Quarter  395.0      [{}]  LEU0252881500    NaN
# 2    1989    M04  2nd Quarter  398.0      [{}]  LEU0252881500    NaN
# 3    1989    M01  1st Quarter  397.0      [{}]  LEU0252881500    NaN
# 4    1988    M10  4th Quarter  392.0      [{}]  LEU0252881500    NaN
# ..    ...    ...          ...    ...       ...            ...    ...
# 145  2010    M05          May    4.6      [{}]    LNS14027662    NaN
# 146  2010    M04        April    4.8      [{}]    LNS14027662    NaN
# 147  2010    M03        March    4.9      [{}]    LNS14027662    NaN
# 148  2010    M02     February    4.9      [{}]    LNS14027662    NaN
# 149  2010    M01      January    4.9      [{}]    LNS14027662    NaN
#
#                                       Category          Type     Bucket  \
# 0                        Earnings - All People      Earnings        Top
# 1                        Earnings - All People      Earnings        Top
# 2                        Earnings - All People      Earnings        Top
# 3                        Earnings - All People      Earnings        Top
# 4                        Earnings - All People      Earnings        Top
# ..                                         ...           ...        ...
# 145  Unemployment Rate - Bachelor's and Higher  Unemployment  Education
# 146  Unemployment Rate - Bachelor's and Higher  Unemployment  Education
# 147  Unemployment Rate - Bachelor's and Higher  Unemployment  Education
# 148  Unemployment Rate - Bachelor's and Higher  Unemployment  Education
# 149  Unemployment Rate - Bachelor's and Higher  Unemployment  Education
#
#           date
# 0   1989-10-01
# 1   1989-07-01
# 2   1989-04-01
# 3   1989-01-01
# 4   1988-10-01
# ..         ...
# 145 2010-05-01
# 146 2010-04-01
# 147 2010-03-01
# 148 2010-02-01
# 149 2010-01-01
#
# [7448 rows x 11 columns]

# %%
# Get stock data.
stocks = pd.read_excel("Stock_Markets_Data.xlsx", header=0)

# Adjust format of stocks data to align with other data.
stocks = stocks.set_index('date').groupby('Category').resample('M').mean().reset_index()
stocks['date'] = stocks['date'] + pd.offsets.MonthBegin(-1)
stocks['year'] = stocks['date'].dt.year

# Add bucket labels
stocks['Type'] = 'Stocks'

# %%
# Load main data and combine DataFrames
main_df = pd.read_pickle("data_final.pkl")
main_df['Type'] = 'CPI'

# Combine all DataFrames.
combo_df = pd.concat([main_df, df, stocks])

# Check format.
combo_df
# Out:
#       year period periodName        value footnotes       series latest  \
# 0     1989    M12   December   126.300000      [{}]  CUSR0000SA0    NaN
# 1     1989    M11   November   125.900000      [{}]  CUSR0000SA0    NaN
# 2     1989    M10    October   125.400000      [{}]  CUSR0000SA0    NaN
# 3     1989    M09  September   124.800000      [{}]  CUSR0000SA0    NaN
# 4     1989    M08     August   124.500000      [{}]  CUSR0000SA0    NaN
# ...    ...    ...        ...          ...       ...          ...    ...
# 1872  2022    NaN        NaN  4435.980526       NaN          NaN    NaN
# 1873  2022    NaN        NaN  4391.265217       NaN          NaN    NaN
# 1874  2022    NaN        NaN  4391.296000       NaN          NaN    NaN
# 1875  2022    NaN        NaN  4040.360000       NaN          NaN    NaN
# 1876  2022    NaN        NaN  3898.946667       NaN          NaN    NaN
#
#              Category Parent Series ID  Level  Leaf       date    Type Bucket
# 0     CPI - All items              NaN    0.0   0.0 1989-12-01     CPI    NaN
# 1     CPI - All items              NaN    0.0   0.0 1989-11-01     CPI    NaN
# 2     CPI - All items              NaN    0.0   0.0 1989-10-01     CPI    NaN
# 3     CPI - All items              NaN    0.0   0.0 1989-09-01     CPI    NaN
# 4     CPI - All items              NaN    0.0   0.0 1989-08-01     CPI    NaN
# ...               ...              ...    ...   ...        ...     ...    ...
# 1872     Stocks - S&P              NaN    NaN   NaN 2022-02-01  Stocks    NaN
# 1873     Stocks - S&P              NaN    NaN   NaN 2022-03-01  Stocks    NaN
# 1874     Stocks - S&P              NaN    NaN   NaN 2022-04-01  Stocks    NaN
# 1875     Stocks - S&P              NaN    NaN   NaN 2022-05-01  Stocks    NaN
# 1876     Stocks - S&P              NaN    NaN   NaN 2022-06-01  Stocks    NaN
#
# [69906 rows x 14 columns]

# %%
# Save DataFrame as pickle.
combo_df.year = combo_df.year.astype(int)
combo_df.to_pickle("combined_data.pkl")
