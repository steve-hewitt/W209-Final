# %%
import requests
import json
import pandas as pd
import altair as alt

# %%
def API_call(series_ids, start_year, end_year):
    '''
    Calls the BLS API to return data. Returns a DataFrame with the combined results.
    '''
    
    ### MAKE SURE TO SET YOUR API KEY BELOW.
    api_key = 'XXXXX'
    
    # Build message to send to API.
    headers = {'Content-type': 'application/json'}
    data = json.dumps({"seriesid": series_ids,"startyear":start_year, "endyear":end_year, "registrationkey":api_key})
    p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/?registrationkey=9026b9bdf3e24f269aa6c29da82a189d', data=data, headers=headers)

    # Parse results.
    j = json.loads(p.text)
    dfs = []
    for x in range(0,len(j["Results"]['series'])):
        t_df = pd.DataFrame(j["Results"]['series'][x]['data'])
        t_df['series'] = j["Results"]['series'][x]['seriesID']
        dfs.append(t_df)
    df = pd.concat(dfs)
    
    return df

# %% [markdown]
# ### CPI Data

# %%
# Import list of targeted CPI-U cateogires.
targets = pd.read_excel("CPI_Category_Tree_Final - REVISED.xlsx", header=0)
targets
# Out:
#                                          Category Name  \
# 0                                      CPI - All items
# 1                             CPI - Food and Beverages
# 2                                   CPI - Food at home
# 3                    CPI - Cereals and bakery products
# 4                 CPI - Meats, poultry, fish, and eggs
# ..                                                 ...
# 141                               CPI - Legal services
# 142                             CPI - Funeral expenses
# 143            CPI - Laundry and dry cleaning services
# 144  CPI* - Apparel services other than laundry and...
# 145                           CPI - Financial services
#
#                         Revised Name                  Revised Name with CPI  \
# 0                          All items                        CPI - All items
# 1                   Food & Beverages                 CPI - Food & Beverages
# 2                       Food at home                     CPI - Food at home
# 3          Cereals & bakery products        CPI - Cereals & bakery products
# 4       Meats, poultry, fish, & eggs     CPI - Meats, poultry, fish, & eggs
# ..                               ...                                    ...
# 141                   Legal services                   CPI - Legal services
# 142                 Funeral expenses                 CPI - Funeral expenses
# 143  Laundry & dry cleaning services  CPI - Laundry & dry cleaning services
# 144           Other apparel services          CPI* - Other apparel services
# 145               Financial services               CPI - Financial services
#
#           Series ID  Level Parent Series ID  Leaf
# 0       CUSR0000SA0      0              NaN     0
# 1       CUSR0000SAF      1      CUSR0000SA0     0
# 2     CUSR0000SAF11      2      CUSR0000SAF     0
# 3    CUSR0000SAF111      3    CUSR0000SAF11     1
# 4    CUSR0000SAF112      3    CUSR0000SAF11     1
# ..              ...    ...              ...   ...
# 141  CUSR0000SEGD01      3     CUSR0000SEGD     1
# 142  CUSR0000SEGD02      3     CUSR0000SEGD     1
# 143  CUSR0000SEGD03      3     CUSR0000SEGD     1
# 144  CUUR0000SEGD04      3     CUSR0000SEGD     1
# 145  CUSR0000SEGD05      3     CUSR0000SEGD     1
#
# [146 rows x 7 columns]

# %%
# Split query inputs into chunks that fit in the API limit.
year_ranges = [(x,x+19) for x in range(1970,2021,20)]
series_ids = list(targets['Series ID'])
series_id_groups = [series_ids[0:50],series_ids[50:100],series_ids[100:150]]

# Send API requests and combine into a single DataFrame
df = pd.concat([API_call(series_id_groups[y], year_ranges[x][0], year_ranges[x][1]) for x in range(0,3) for y in range(0,3)])

# %%
# Merge other data into results from API pull.
series_names = targets.set_index('Series ID').to_dict()['Revised Name with CPI']
df['Category'] = df['series'].map(series_names)
parent_IDs = targets.set_index('Series ID').to_dict()['Parent Series ID']
df['Parent Series ID'] = df['series'].map(parent_IDs)
levels = targets.set_index('Series ID').to_dict()['Level']
df['Level'] = df['series'].map(levels)
leaves = targets.set_index('Series ID').to_dict()['Leaf']
df['Leaf'] = df['series'].map(leaves)

# Convert month and year to a datetime column.
df['date'] = pd.to_datetime(df.year.astype(str) + '/' + df.period.str[1:] + '/01')

# Make sure values are stored as numbers and not as strings.
df.value = df.value.astype(float)

# %% [markdown]
# ### Non-CPI Data

# %%
# Import list of targeted non-CPI cateogires.
targets = pd.read_excel("Other_BLS_Data_Final - REVISED.xlsx", header=0)
targets
# Out:
#                                  Category Name   Revised Category Name  \
# 0                        Earnings - All People                 E - All
# 1                               Earnings - Men                 E - Men
# 2                             Earnings - Women               E - Women
# 3                      Earnings - White People        E - White People
# 4                         Earnings - White Men           E - White Men
# 5                       Earnings - White Women         E - White Women
# 6                      Earnings - Black People        E - Black People
# 7                         Earnings - Black Men           E - Black Men
# 8                       Earnings - Black Women         E - Black Women
# 9                      Earnings - Asian People        E - Asian People
# 10                        Earnings - Asian Men           E - Asian Men
# 11                      Earnings - Asian Women         E - Asian Women
# 12                  Earnings - Hispanic People     E - Hispanic People
# 13                     Earnings - Hispanic Men        E - Hispanic Men
# 14                   Earnings - Hispanic Women      E - Hispanic Women
# 15           Earnings - High School Unfinished     E - H.S. Unfinished
# 16             Earnings - High School Finished       E - H.S. Finished
# 17                     Earnings - Some College        E - Some College
# 18                Earnings - Bachelor's Degree   E - Bachelor's Degree
# 19                  Earnings - Advanced Degree     E - Advanced Degree
# 20              Unemployment Rate - All People                 U - All
# 21                     Unemployment Rate - Men                 U - Men
# 22                   Unemployment Rate - Women               U - Women
# 23            Unemployment Rate - White People        U - White People
# 24            Unemployment Rate - Black People        U - Black People
# 25            Unemployment Rate - Asian People        U - Asian People
# 26         Unemployment Rate - Hispanic People     U - Hispanic People
# 27  Unemployment Rate - High School Unfinished     U - H.S. Unfinished
# 28    Unemployment Rate - High School Finished       U - H.S. Finished
# 29            Unemployment Rate - Some College        U - Some College
# 30   Unemployment Rate - Bachelor's and Higher  U - Bachelors & Higher
#
#         Series ID          Type              Bucket
# 0   LEU0252881500      Earnings               Total
# 1   LEU0252881800      Earnings           By Gender
# 2   LEU0252882700      Earnings           By Gender
# 3   LEU0252883600      Earnings             By Race
# 4   LEU0252883900      Earnings  By Race and Gender
# 5   LEU0252884200      Earnings  By Race and Gender
# 6   LEU0252884500      Earnings             By Race
# 7   LEU0252884800      Earnings  By Race and Gender
# 8   LEU0252885100      Earnings  By Race and Gender
# 9   LEU0254468400      Earnings             By Race
# 10  LEU0254468500      Earnings  By Race and Gender
# 11  LEU0254468600      Earnings  By Race and Gender
# 12  LEU0252885400      Earnings             By Race
# 13  LEU0252885700      Earnings  By Race and Gender
# 14  LEU0252886000      Earnings  By Race and Gender
# 15  LEU0252916700      Earnings        By Education
# 16  LEU0252917300      Earnings        By Education
# 17  LEU0254929400      Earnings        By Education
# 18  LEU0252919100      Earnings        By Education
# 19  LEU0252919700      Earnings        By Education
# 20    LNS14000000  Unemployment               Total
# 21    LNS14000001  Unemployment           By Gender
# 22    LNS14000002  Unemployment           By Gender
# 23    LNS14000003  Unemployment             By Race
# 24    LNS14000006  Unemployment             By Race
# 25    LNS14032183  Unemployment             By Race
# 26    LNS14000009  Unemployment             By Race
# 27    LNS14027659  Unemployment        By Education
# 28    LNS14027660  Unemployment        By Education
# 29    LNS14027689  Unemployment        By Education
# 30    LNS14027662  Unemployment        By Education

# %%
# Split query inputs into chunks that fit in the API limit.
year_ranges = [(x,x+19) for x in range(1970,2021,20)]
series_ids = list(targets['Series ID'])
series_id_groups = [series_ids[0:50]]

# Send API requests and combine into a single DataFrame
df2 = pd.concat([API_call(series_id_groups[y], year_ranges[x][0], year_ranges[x][1]) for x in range(0,3) for y in range(0,1)])

# %%
# Merge other data into results from API pull.
series_names = targets.set_index('Series ID').to_dict()['Revised Category Name']
df2['Category'] = df2['series'].map(series_names)
types = targets.set_index('Series ID').to_dict()['Type']
df2['Type'] = df2['series'].map(types)
buckets = targets.set_index('Series ID').to_dict()['Bucket']
df2['Bucket'] = df2['series'].map(buckets)

# Convert quarter names to months.
df2['period'].replace(to_replace = ['Q01', 'Q02', 'Q03', 'Q04'], value = ['M03', 'M06', 'M09', 'M12'], inplace = True)

# Convert month and year to a datetime column.
df2['date'] = pd.to_datetime(df2.year.astype(str) + '/' + df2.period.str[1:] + '/01')

# Make sure values are stored as numbers and not as strings.
df2.value = df2.value.astype(float)

# %%
# Get stock data.
stocks = pd.read_excel("Stock_Markets_Data - REVISED.xlsx", header=0)

# User revised category names
stocks['Category'] = stocks['Revised Category']

# Adjust format of stocks data to align with other data.
stocks = stocks.set_index('date').groupby('Category').resample('M').mean().reset_index()
stocks['date'] = stocks['date'] + pd.offsets.MonthBegin(-1)
stocks['year'] = stocks['date'].dt.year

# Add bucket labels
stocks['Type'] = 'Stocks'

# %%
combo_df = pd.concat([df, df2, stocks])

# %%
# Save DataFrame as pickle.
combo_df.year = combo_df.year.astype(int)
combo_df.to_pickle("combined_data.pkl")

# %%
# Check data
combo_df
# Out:
#       year period periodName        value footnotes       series latest  \
# 0     1989    M12   December   126.300000      [{}]  CUSR0000SA0    NaN
# 1     1989    M11   November   125.900000      [{}]  CUSR0000SA0    NaN
# 2     1989    M10    October   125.400000      [{}]  CUSR0000SA0    NaN
# 3     1989    M09  September   124.800000      [{}]  CUSR0000SA0    NaN
# 4     1989    M08     August   124.500000      [{}]  CUSR0000SA0    NaN
# ...    ...    ...        ...          ...       ...          ...    ...
# 1872  2022    NaN        NaN  4435.980526       NaN          NaN    NaN
# 1873  2022    NaN        NaN  4391.265217       NaN          NaN    NaN
# 1874  2022    NaN        NaN  4391.296000       NaN          NaN    NaN
# 1875  2022    NaN        NaN  4040.360000       NaN          NaN    NaN
# 1876  2022    NaN        NaN  3898.946667       NaN          NaN    NaN
#
#              Category Parent Series ID  Level  Leaf       date    Type Bucket
# 0     CPI - All items              NaN    0.0   0.0 1989-12-01     NaN    NaN
# 1     CPI - All items              NaN    0.0   0.0 1989-11-01     NaN    NaN
# 2     CPI - All items              NaN    0.0   0.0 1989-10-01     NaN    NaN
# 3     CPI - All items              NaN    0.0   0.0 1989-09-01     NaN    NaN
# 4     CPI - All items              NaN    0.0   0.0 1989-08-01     NaN    NaN
# ...               ...              ...    ...   ...        ...     ...    ...
# 1872          S - S&P              NaN    NaN   NaN 2022-02-01  Stocks    NaN
# 1873          S - S&P              NaN    NaN   NaN 2022-03-01  Stocks    NaN
# 1874          S - S&P              NaN    NaN   NaN 2022-04-01  Stocks    NaN
# 1875          S - S&P              NaN    NaN   NaN 2022-05-01  Stocks    NaN
# 1876          S - S&P              NaN    NaN   NaN 2022-06-01  Stocks    NaN
#
# [69926 rows x 14 columns]
